# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.0
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/panodphol/anaconda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     ca-certificates-2018.10.15 |       ha4d7672_0         135 KB  conda-forge
#     openssl-1.0.2p             |       h470a237_1         2.9 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0             conda-forge
#     geopy:           1.17.0-py_0           conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2017.08.26-ha1e5d58_0             --> 2018.10.15-ha4d7672_0 conda-forge
#     openssl:         1.0.2o-h26aff7b_0                 --> 1.0.2p-h470a237_1     conda-forge
#
#
# Downloading and Extracting Packages
# geopy 1.17.0: ########################################################## | 100%
# ca-certificates 2018.10.15: ############################################ | 100%
# openssl 1.0.2p: ######################################################## | 100%
# geographiclib 1.49: #################################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.0
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/panodphol/anaconda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-2.2.2               |        py36_1001         493 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     numpy-base-1.14.3          |   py36h7ef55bc_1         3.9 MB
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     libopenblas-0.2.20         |       hdc02c5d_7         9.9 MB
#     numpy-1.14.3               |   py36he6379a5_1          41 KB
#     pandas-0.23.4              |   py36hf8a1672_0        10.2 MB  conda-forge
#     libgfortran-3.0.1          |       h93005f0_2         495 KB
#     ------------------------------------------------------------
#                                            Total:        25.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:      2.2.2-py36_1001       conda-forge
#     branca:      0.3.1-py_0            conda-forge
#     folium:      0.5.0-py_0            conda-forge
#     libgfortran: 3.0.1-h93005f0_2
#     libopenblas: 0.2.20-hdc02c5d_7
#     numpy-base:  1.14.3-py36h7ef55bc_1
#     vincent:     0.4.4-py_1            conda-forge
#
# The following packages will be UPDATED:
#
#     numpy:       1.12.1-py36_0                     --> 1.14.3-py36he6379a5_1
#     pandas:      0.20.1-np112py36_0                --> 0.23.4-py36hf8a1672_0 conda-forge
#
#
# Downloading and Extracting Packages
# vincent 0.4.4: ######################################################### | 100%
# altair 2.2.2: ########################################################## | 100%
# folium 0.5.0: ########################################################## | 100%
# numpy-base 1.14.3: ##################################################### | 100%
# branca 0.3.1: ########################################################## | 100%
# libopenblas 0.2.20: #################################################### | 100%
# numpy 1.14.3: ########################################################## | 100%
# pandas 0.23.4: ######################################################### | 100%
# libgfortran 3.0.1: ##################################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'CNONKP5B5Z3EIWUCBKUEE4B2KZVFGHTH5ZTOBTB00K31HKG5' # your Foursquare ID
CLIENT_SECRET = 'HYEWVB3DWYOAQMZFU45CUU55SYCYQRPOX5OKISHUK5EFWQSQ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CNONKP5B5Z3EIWUCBKUEE4B2KZVFGHTH5ZTOBTB00K31HKG5
# CLIENT_SECRET:HYEWVB3DWYOAQMZFU45CUU55SYCYQRPOX5OKISHUK5EFWQSQ

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /Users/panodphol/anaconda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# 40.7149555 -74.0153365

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CNONKP5B5Z3EIWUCBKUEE4B2KZVFGHTH5ZTOBTB00K31HKG5&client_secret=HYEWVB3DWYOAQMZFU45CUU55SYCYQRPOX5OKISHUK5EFWQSQ&ll=40.7149555,-74.0153365&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5bec31ed4c1f6717d300a5d0'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'primary': True,
#       'shortName': 'Pizza'}],
#     'delivery': {'id': '294544',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544'},
#     'hasPerk': False,
#     'id': '4fa862b3e4b0ebff2f749f06',
#     'location': {'address': '225 Murray St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 58,
#      'formattedAddress': ['225 Murray St',
#       'New York, NY 10282',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71521779064671,
#        'lng': -74.01473940209351}],
#      'lat': 40.71521779064671,
#      'lng': -74.01473940209351,
#      'postalCode': '10282',
#      'state': 'NY'},
#     'name': "Harry's Italian Pizza Bar",
#     'referralId': 'v-1542205933'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f3232e219836c91c7bfde94',
#     'location': {'address': '63 W Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 446,
#      'formattedAddress': ['63 W Broadway',
#       'New York, NY 10007',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71446,
#        'lng': -74.010086}],
#      'lat': 40.71446,
#      'lng': -74.010086,
#      'postalCode': '10007',
#      'state': 'NY'},
#     'name': 'Conca Cucina Italian Restaurant',
#     'referralId': 'v-1542205933'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '3fd66200f964a520f4e41ee3',
#     'location': {'address': '124 Chambers St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn Church St & W Broadway',
#      'distance': 549,
#      'formattedAddress': ['124 Chambers St (btwn Church St & W Broadway)',
#       'New York, NY 10007',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71533713859952,
#        'lng': -74.00884766217825}],
#      'lat': 40.71533713859952,
#      'lng': -74.00884766217825,
#      'postalCode': '10007',
#      'state': 'NY'},
#     'name': 'Ecco',
#     'referralId': 'v-1542205933'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...      294544
# 1  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...         NaN
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
#
#                 delivery.provider.icon.name  \
# 0  /delivery_provider_seamless_20180129.png
# 1                                       NaN
# 2                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0               seamless  https://www.seamless.com/menu/harrys-italian-p...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
#
#    hasPerk                        id location.address      ...       \
# 0    False  4fa862b3e4b0ebff2f749f06    225 Murray St      ...
# 1    False  4f3232e219836c91c7bfde94    63 W Broadway      ...
# 2    False  3fd66200f964a520f4e41ee3  124 Chambers St      ...
#
#           location.crossStreet location.distance  \
# 0                          NaN                58
# 1                          NaN               446
# 2  btwn Church St & W Broadway               549
#
#                            location.formattedAddress  \
# 0  [225 Murray St, New York, NY 10282, United Sta...
# 1  [63 W Broadway, New York, NY 10007, United Sta...
# 2  [124 Chambers St (btwn Church St & W Broadway)...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.71521779064671...     40.715218
# 1  [{'label': 'display', 'lat': 40.71446, 'lng': ...     40.714460
# 2  [{'label': 'display', 'lat': 40.71533713859952...     40.715337
#
#   location.lng location.postalCode  location.state  \
# 0   -74.014739               10282              NY
# 1   -74.010086               10007              NY
# 2   -74.008848               10007              NY
#
#                               name    referralId
# 0        Harry's Italian Pizza Bar  v-1542205933
# 1  Conca Cucina Italian Restaurant  v-1542205933
# 2                             Ecco  v-1542205933
#
# [3 rows x 23 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                               name          categories          address  cc  \
# 0        Harry's Italian Pizza Bar         Pizza Place    225 Murray St  US
# 1  Conca Cucina Italian Restaurant                Food    63 W Broadway  US
# 2                             Ecco  Italian Restaurant  124 Chambers St  US
#
#        city        country                  crossStreet  distance  \
# 0  New York  United States                          NaN        58
# 1  New York  United States                          NaN       446
# 2  New York  United States  btwn Church St & W Broadway       549
#
#                                     formattedAddress  \
# 0  [225 Murray St, New York, NY 10282, United Sta...
# 1  [63 W Broadway, New York, NY 10007, United Sta...
# 2  [124 Chambers St (btwn Church St & W Broadway)...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.71521779064671...  40.715218 -74.014739
# 1  [{'label': 'display', 'lat': 40.71446, 'lng': ...  40.714460 -74.010086
# 2  [{'label': 'display', 'lat': 40.71533713859952...  40.715337 -74.008848
#
#   postalCode state                        id
# 0      10282    NY  4fa862b3e4b0ebff2f749f06
# 1      10007    NY  4f3232e219836c91c7bfde94
# 2      10007    NY  3fd66200f964a520f4e41ee3

# %%
dataframe_filtered.name
# Out:
# 0          Harry's Italian Pizza Bar
# 1    Conca Cucina Italian Restaurant
# 2                               Ecco
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=CNONKP5B5Z3EIWUCBKUEE4B2KZVFGHTH5ZTOBTB00K31HKG5&client_secret=HYEWVB3DWYOAQMZFU45CUU55SYCYQRPOX5OKISHUK5EFWQSQ&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'type': 'outdoorSeating'},
#    {'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}],
#     'name': 'Menus',
#     'summary': 'Happy Hour, Brunch & more',
#     'type': 'serves'},
#    {'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}],
#     'name': 'Drinks',
#     'summary': 'Beer, Wine & Cocktails',
#     'type': 'drinks'},
#    {'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}],
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'type': 'diningOptions'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1336776717,
#   'height': 640,
#   'id': '4fad980de4b091b4626c3633',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#   'visibility': 'public',
#   'width': 480},
#  'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1ca941735',
#    'name': 'Pizza Place',
#    'pluralName': 'Pizza Places',
#    'primary': True,
#    'shortName': 'Pizza'},
#   {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#    'value': -13619152},
#   'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633', 'value': -1}},
#  'contact': {'formattedPhone': '(212) 608-1007', 'phone': '2126081007'},
#  'createdAt': 1336435379,
#  'delivery': {'id': '294544',
#   'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#     'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50]},
#    'name': 'seamless'},
#   'url': 'https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544'},
#  'dislike': False,
#  'hasMenu': True,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'hours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': False,
#   'richStatus': {'entities': [], 'text': 'Closed until 11:30 AM'},
#   'status': 'Closed until 11:30 AM',
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'id': '4fa862b3e4b0ebff2f749f06',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 117,
#   'groups': [{'count': 117, 'items': [], 'type': 'others'}],
#   'summary': '117 Likes'},
#  'listed': {'count': 50,
#   'groups': [{'count': 50,
#     'items': [{'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#       'collaborative': False,
#       'createdAt': 1336094672,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 22},
#       'id': '4fa32fd0e4b04193744746b1',
#       'listItems': {'count': 187,
#        'items': [{'createdAt': 1342934485,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Manhattan Haunts',
#       'photo': {'createdAt': 1317849414,
#        'height': 330,
#        'id': '4e8cc9461081e3b3544e12e5',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#        'user': {'firstName': 'Time Out New York',
#         'gender': 'none',
#         'id': '742542',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#         'type': 'page'},
#        'visibility': 'public',
#        'width': 492},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1380845377,
#       'url': '/becca_mcarthur/list/manhattan-haunts',
#       'user': {'firstName': 'Becca',
#        'gender': 'female',
#        'id': '24592223',
#        'lastName': 'McArthur',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#       'collaborative': False,
#       'createdAt': 1336836475,
#       'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#       'editable': False,
#       'followers': {'count': 20},
#       'id': '4fae817be4b085f6b2a74d19',
#       'listItems': {'count': 272,
#        'items': [{'createdAt': 1373909433,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'USA NYC MAN FiDi',
#       'photo': {'createdAt': 1436043666,
#        'height': 960,
#        'id': '55984992498e13ba75e353bb',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#        'user': {'firstName': 'Kino',
#         'gender': 'male',
#         'id': '12113441',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#        'visibility': 'public',
#        'width': 540},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1536019882,
#       'url': '/kinosfault/list/usa-nyc-man-fidi',
#       'user': {'firstName': 'Kino',
#        'gender': 'male',
#        'id': '12113441',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/sweetiewill/list/foodie-love-in-ny--02',
#       'collaborative': False,
#       'createdAt': 1382467210,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 7},
#       'id': '5266c68a498e7c667807fe09',
#       'listItems': {'count': 200,
#        'items': [{'createdAt': 1386809936,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Foodie Love in NY - 02',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1391995585,
#       'url': '/sweetiewill/list/foodie-love-in-ny--02',
#       'user': {'firstName': 'WiLL',
#        'gender': 'male',
#        'id': '547977',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-Q5NYGDMFDMOITQRR.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/rickr7/list/nyc-resturants',
#       'collaborative': True,
#       'createdAt': 1339944944,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 12},
#       'id': '4fddeff0e4b0e078037ac0d3',
#       'listItems': {'count': 200,
#        'items': [{'createdAt': 1514680908,
#          'id': 't54ed3b13498e857fd7dbb6fc'}]},
#       'name': 'NYC Resturants',
#       'photo': {'createdAt': 1349704979,
#        'height': 800,
#        'id': '5072dd13e4b09145cdf782d1',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/208205_fGh2OuAZ9qJ4agbAA5wMVNOSIm9kNUlRtNwj1N-adqg.jpg',
#        'user': {'firstName': 'Thalia',
#         'gender': 'female',
#         'id': '208205',
#         'lastName': 'K',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/SNOOLCAW2AG04ZKD.jpg'}},
#        'visibility': 'public',
#        'width': 800},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1541109721,
#       'url': '/rickr7/list/nyc-resturants',
#       'user': {'firstName': 'Richard',
#        'gender': 'male',
#        'id': '21563126',
#        'lastName': 'Revilla',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/21563126_v05J1KPw_SVj6Ehq9g8B9jeAGjFUMsU5QGl-NZ8inUQ7pKQm5bKplW37EmR7jS2A7GYPBBAtl.jpg'}}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '225 Murray St',
#   'cc': 'US',
#   'city': 'New York',
#   'country': 'United States',
#   'formattedAddress': ['225 Murray St', 'New York, NY 10282', 'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351}],
#   'lat': 40.71521779064671,
#   'lng': -74.01473940209351,
#   'postalCode': '10282',
#   'state': 'NY'},
#  'menu': {'anchor': 'View Menu',
#   'label': 'Menu',
#   'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu',
#   'type': 'Menu',
#   'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu'},
#  'name': "Harry's Italian Pizza Bar",
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 145,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 145,
#     'items': [{'createdAt': 1336776717,
#       'height': 640,
#       'id': '4fad980de4b091b4626c3633',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#       'user': {'firstName': 'Leony',
#        'gender': 'none',
#        'id': '13676709',
#        'lastName': 'Naciri',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#       'visibility': 'public',
#       'width': 480},
#      {'createdAt': 1362767440,
#       'height': 959,
#       'id': '513a2e50e4b08ac082454376',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'suffix': '/6195366_2CTGLooEIZ-oVxZlMGjQFunPJuwJql1jtFnIf69-8Tw.jpg',
#       'user': {'firstName': 'Michelle',
#        'gender': 'female',
#        'id': '6195366',
#        'lastName': 'Thornton',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2RJUIIDMSRLF1UOE.jpg'}},
#       'visibility': 'public',
#       'width': 717}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'popular': {'isLocalHoliday': False,
#   'isOpen': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#  'rating': 7.1,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 206,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'shortUrl': 'http://4sq.com/JNblHV',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 55},
#  'timeZone': 'America/New_York',
#  'tips': {'count': 55,
#   'groups': [{'count': 55,
#     'items': [{'agreeCount': 4,
#       'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#       'createdAt': 1406302473,
#       'disagreeCount': 0,
#       'id': '53d27909498e0523841340b6',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'count': 4,
#          'items': [{'firstName': 'P.',
#            'gender': 'male',
#            'id': '369426',
#            'lastName': 'M.',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/JPQYUWJKUT0H2OO4.jpg'}},
#           {'firstName': 'Diane',
#            'gender': 'female',
#            'id': '87587879',
#            'lastName': 'Danneels',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#           {'firstName': 'Tim',
#            'gender': 'male',
#            'id': '87591341',
#            'lastName': 'Sheehan',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#           {'firstName': 'TenantKing.com',
#            'gender': 'none',
#            'id': '87473404',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#            'type': 'page'}],
#          'type': 'others'}],
#        'summary': '4 likes'},
#       'logView': True,
#       'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'TenantKing.com',
#        'gender': 'none',
#        'id': '87473404',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#        'type': 'page'}},
#      {'agreeCount': 2,
#       'authorInteractionType': 'liked',
#       'canonicalUrl': 'https://foursquare.com/item/53962e98498ecd43845cc813',
#       'createdAt': 1402351256,
#       'disagreeCount': 0,
#       'id': '53962e98498ecd43845cc813',
#       'lang': 'en',
#       'likes': {'count': 2,
#        'groups': [{'count': 2,
#          'items': [{'firstName': 'Hani',
#            'gender': 'male',
#            'id': '7012699',
#            'lastName': 'Alawadi',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/2ZMJFSP2Z4R5NBVX.jpg'}},
#           {'firstName': 'Leena',
#            'gender': 'female',
#            'id': '61939758',
#            'lastName': 'Ragheb',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/61939758_-ott2m3s_tFuSoJleuCIaNCsRRGtLhx38m65oHrz3aZPUOJysjjcMCikrogIT9l-VqMPddqLy.jpg'}}],
#          'type': 'others'}],
#        'summary': '2 likes'},
#       'logView': True,
#       'photo': {'createdAt': 1402351260,
#        'height': 720,
#        'id': '53962e9c498e53dbbf59b28e',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'suffix': '/7012699_DCcCtW8oRbhNv62E68gxtLnWn7IgRhapBr8vdnIQjYk.jpg',
#        'visibility': 'public',
#        'width': 720},
#       'photourl': 'https://fastly.4sqi.net/img/general/original/7012699_DCcCtW8oRbhNv62E68gxtLnWn7IgRhapBr8vdnIQjYk.jpg',
#       'text': "I'm not sure if this place is one of the famous pizzerias in NYC but I loved their pizza.",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'Hani',
#        'gender': 'male',
#        'id': '7012699',
#        'lastName': 'Alawadi',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2ZMJFSP2Z4R5NBVX.jpg'}}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'http://harrysitalian.com',
#  'verified': False}

# %%
latitude = 40.715337
longitude = -74.008848

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=CNONKP5B5Z3EIWUCBKUEE4B2KZVFGHTH5ZTOBTB00K31HKG5&client_secret=HYEWVB3DWYOAQMZFU45CUU55SYCYQRPOX5OKISHUK5EFWQSQ&ll=40.715337,-74.008848&v=20180604&radius=500&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4af5d65ff964a52091fd21e3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d1f8941735',
#     'name': 'Furniture / Home Store',
#     'pluralName': 'Furniture / Home Stores',
#     'primary': True,
#     'shortName': 'Furniture / Home'}],
#   'id': '4af5d65ff964a52091fd21e3',
#   'location': {'address': '57 Warren St',
#    'cc': 'US',
#    'city': 'New York',
#    'country': 'United States',
#    'crossStreet': 'Church St',
#    'distance': 73,
#    'formattedAddress': ['57 Warren St (Church St)',
#     'New York, NY 10007',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71482437714839,
#      'lng': -74.00940425461492}],
#    'lat': 40.71482437714839,
#    'lng': -74.00940425461492,
#    'neighborhood': 'Tribeca',
#    'postalCode': '10007',
#    'state': 'NY'},
#   'name': 'Korin',
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '33104775'}}}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                     name                     categories           address  cc  \
# 0                  Korin         Furniture / Home Store      57 Warren St  US
# 1       Takahachi Bakery                         Bakery      25 Murray St  US
# 2  Chambers Street Wines                      Wine Shop   148 Chambers St  US
# 3              Takahachi               Sushi Restaurant      145 Duane St  US
# 4            Juice Press  Vegetarian / Vegan Restaurant      83 Murray St  US
# 5              Nish Nūsh             Falafel Restaurant       88 Reade St  US
# 6        Mulberry & Vine                           Café      73 Warren St  US
# 7        Equinox Tribeca                            Gym  54 Murray Street  US
# 8           Ten Over Ten                     Nail Salon      112 Reade St  US
# 9            Little Park            American Restaurant     85 W Broadway  US
#
#        city        country                     crossStreet  distance  \
# 0  New York  United States                       Church St        73
# 1  New York  United States                    at Church St       179
# 2  New York  United States  btwn West Broadway & Hudson St        88
# 3  New York  United States     btwn W Broadway & Church St       146
# 4  New York  United States  btwn Greenwich St & W Broadway       202
# 5  New York  United States                    at Church St        97
# 6  New York  United States  btwn W Broadway & Greenwich St       117
# 7  New York  United States                   at W Broadway       159
# 8  New York  United States                             NaN        68
# 9  New York  United States                  at Chambers St        29
#
#                                     formattedAddress  \
# 0  [57 Warren St (Church St), New York, NY 10007,...
# 1  [25 Murray St (at Church St), New York, NY 100...
# 2  [148 Chambers St (btwn West Broadway & Hudson ...
# 3  [145 Duane St (btwn W Broadway & Church St), N...
# 4  [83 Murray St (btwn Greenwich St & W Broadway)...
# 5  [88 Reade St (at Church St), New York, NY 1001...
# 6  [73 Warren St (btwn W Broadway & Greenwich St)...
# 7  [54 Murray Street (at W Broadway), New York, N...
# 8  [112 Reade St, New York, NY 10013, United States]
# 9  [85 W Broadway (at Chambers St), New York, NY ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.71482437714839...  40.714824 -74.009404
# 1  [{'label': 'display', 'lat': 40.71372322632139...  40.713723 -74.008733
# 2  [{'label': 'display', 'lat': 40.71577306392837...  40.715773 -74.009718
# 3  [{'label': 'display', 'lat': 40.71652647412374...  40.716526 -74.008101
# 4  [{'label': 'display', 'lat': 40.71478769908051...  40.714788 -74.011132
# 5  [{'label': 'display', 'lat': 40.71553710116416...  40.715537 -74.007725
# 6  [{'label': 'display', 'lat': 40.71517693966315...  40.715177 -74.010227
# 7  [{'label': 'display', 'lat': 40.714057, 'lng':...  40.714057 -74.009694
# 8  [{'label': 'display', 'lat': 40.71594125566931...  40.715941 -74.008721
# 9  [{'label': 'display', 'lat': 40.71548658524973...  40.715487 -74.009133
#
#   neighborhood postalCode state                        id
# 0      Tribeca      10007    NY  4af5d65ff964a52091fd21e3
# 1          NaN      10007    NY  4c154c9a77cea593c401d260
# 2          NaN      10007    NY  4adcf23cf964a520cc6221e3
# 3          NaN      10013    NY  4a8f2f39f964a520471420e3
# 4          NaN      10007    NY  54148bc6498ea7bb8c05b70a
# 5          NaN      10013    NY  50ba9119e4b071a4bae6dc10
# 6          NaN      10007    NY  5171b5cc011cef9833bbb787
# 7          NaN      10007    NY  4a6e331af964a52031d41fe3
# 8          NaN      10013    NY  4ce2a27cd58c60fc0fa1a76f
# 9          NaN      10007    NY  545c0436498e798e22ce4b2a

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
